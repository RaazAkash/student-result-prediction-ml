# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_result.csv");

# %%
df.head()
# Out:
#    study_hours  attendance  assignment_score result
# 0            6          78                31   Pass
# 1            3          79                40   Fail
# 2           10          53                93   Pass
# 3            7          71                50   Pass
# 4            4          90                47   Pass

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   study_hours       1000 non-null   int64
#  1   attendance        1000 non-null   int64
#  2   assignment_score  1000 non-null   int64
#  3   result            1000 non-null   str
# dtypes: int64(3), str(1)
# memory usage: 31.4 KB

# %%
df.describe()
# Out:
#        study_hours   attendance  assignment_score
# count   1000.00000  1000.000000       1000.000000
# mean       4.84000    70.581000         63.370000
# std        3.15854    17.318758         20.491828
# min        0.00000    40.000000         30.000000
# 25%        2.00000    56.000000         46.000000
# 50%        5.00000    71.000000         62.000000
# 75%        8.00000    85.250000         80.000000
# max       10.00000   100.000000        100.000000

# %%
df['result'].unique()
# Out:
# <StringArray>
# ['Pass', 'Fail']
# Length: 2, dtype: str

# %%
df.isnull().sum()
# Out:
# study_hours         0
# attendance          0
# assignment_score    0
# result              0
# dtype: int64

# %%
x = df[['study_hours','attendance','assignment_score']]

# %%
y= df[['result']]

# %%
x.head()
# Out:
#    study_hours  attendance  assignment_score
# 0            6          78                31
# 1            3          79                40
# 2           10          53                93
# 3            7          71                50
# 4            4          90                47

# %%
y.head()
# Out:
#   result
# 0   Pass
# 1   Fail
# 2   Pass
# 3   Pass
# 4   Pass

# %%
df.count
# Out:
# <bound method DataFrame.count of      study_hours  attendance  assignment_score result
# 0              6          78                31   Pass
# 1              3          79                40   Fail
# 2             10          53                93   Pass
# 3              7          71                50   Pass
# 4              4          90                47   Pass
# ..           ...         ...               ...    ...
# 995            9          87                50   Pass
# 996            8          96                57   Pass
# 997            1          99                91   Pass
# 998            7          61                62   Pass
# 999            7          93                64   Pass
#
# [1000 rows x 4 columns]>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.count
# Out:
# <bound method DataFrame.count of      study_hours  attendance  assignment_score
# 29            10          47                51
# 535            0          60                92
# 695           10          86                59
# 557            4          57                65
# 836            5          70                74
# ..           ...         ...               ...
# 106            7          72                41
# 270            7          42                75
# 860            0          71                32
# 435            6          88                43
# 102            9          52                35
#
# [800 rows x 3 columns]>

# %%
x_test.count
# Out:
# <bound method DataFrame.count of      study_hours  attendance  assignment_score
# 521            2          54                50
# 737            1          81                75
# 740            4          79                86
# 660            4          45                75
# 411            7          49                84
# ..           ...         ...               ...
# 408            9          96                98
# 332            0          59                79
# 208           10          79                76
# 613            7          68                81
# 78             4          66                57
#
# [200 rows x 3 columns]>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\IDL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array(['Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail',
#        'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass',
#        'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Fail', 'Pass', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass',
#        'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Pass', 'Fail',
#        'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass',
#        'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Fail', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass',
#        'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass',
#        'Pass', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail',
#        'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass',
#        'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Pass',
#        'Fail', 'Fail', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass',
#        'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Pass',
#        'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Fail', 'Pass',
#        'Pass', 'Fail', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,pred))
# Out:
# 0.985

# %%
score=(accuracy_score(y_test,pred))

# %%
print("You prediction score using RandomForestClassifier Model", score*100,"%")
# Out:
# You prediction score using RandomForestClassifier Model 98.5 %

# %%
df['study_hours'].hist()
plt.show()
